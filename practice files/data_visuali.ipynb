# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dataset/Ice Cream Ratings.csv')
df = df.set_index('Date')
df
# Out:
#           Flavor Rating  Texture Rating  Overall Rating
# Date
# 1/1/2022       0.223090        0.040220        0.600129
# 1/2/2022       0.635886        0.938476        0.106264
# 1/3/2022       0.442323        0.044154        0.598112
# 1/4/2022       0.389128        0.549676        0.489353
# 1/5/2022       0.386887        0.519439        0.988280
# 1/6/2022       0.877984        0.193588        0.832827
# 1/7/2022       0.140995        0.325110        0.105147

# %%
df.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# line plot
df.plot(kind = 'line', subplots = True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %%
df.plot(kind = 'line', title = 'Ice Cream Ratings', xlabel = 'Date', ylabel = 'Rating')
# Out:
# <Axes: title={'center': 'Ice Cream Ratings'}, xlabel='Date', ylabel='Rating'>

# %% [markdown]
# # bar plot

# %%
df.plot(kind = 'bar')
# Out:
# <Axes: xlabel='Date'>

# %%
# stacked bar plot
df.plot(kind = 'bar', stacked=True)
# Out:
# <Axes: xlabel='Date'>

# %%
df['Flavor Rating'].plot(kind = 'bar', stacked=True)
# Out:
# <Axes: xlabel='Date'>

# %%
# horizontal bar plot
df.plot.barh(stacked = True)
# Out:
# <Axes: ylabel='Date'>

# %% [markdown]
# # scatter plot

# %%
df.plot.scatter(x = 'Texture Rating', y= 'Overall Rating', s = 500, c = 'Green') # s is size of the dots, while c is the color
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Overall Rating'>

# %% [markdown]
# # histogram

# %%
df.plot.hist(bins = 100)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # boxplot

# %%
df.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# # area plot

# %%
df.plot.area(figsize = (10, 5))
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot.pie(y = 'Flavor Rating', figsize = (5, 5))
# Out:
# <Axes: ylabel='Flavor Rating'>
